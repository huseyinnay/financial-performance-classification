# %%
import numpy as np
import pandas as pd

# %%
financial_data = pd.read_csv("../data/raw/financial_data.csv")

# %%
financial_data.head()
# Out:
#     Revenue  Cost of Goods Sold  Gross Profit  Operating Expenses    EBITDA  \
# 0  0.496714           -0.138264      0.647689            1.523030 -0.234153
# 1  1.031000            0.931280     -0.839218           -0.309212  0.331263
# 2  0.257550           -0.074446     -1.918771           -0.026514  0.060230
# 3  1.158596           -0.820682      0.963376            0.412781  0.822060
# 4 -0.772825           -0.236819     -0.485364            0.081874  2.314659
#
#    Net Income  Total Assets  Total Liabilities    Equity  Operating Cash Flow  \
# 0   -0.234137      1.579213           0.767435 -0.469474             0.542560
# 1    0.975545     -0.479174          -0.185659 -1.106335            -1.196207
# 2    2.463242     -0.192361           0.301547 -0.034712            -1.168678
# 3    1.896793     -0.245388          -0.753736 -0.889514            -0.815810
# 4   -1.867265      0.686260          -1.612716 -0.471932             1.088951
#
#    ...      EBIT     NOPAT  Total Debt  Short-term Debt  Long-term Debt  \
# 0  ... -1.478522 -0.719844   -0.460639         1.057122        0.343618
# 1  ...  0.005113 -0.234587   -1.415371        -0.420645       -0.342715
# 2  ... -0.680025  0.232254    0.293072        -0.714351        1.865775
# 3  ...  0.515035  0.513786    0.515048         3.852731        0.570891
# 4  ... -0.926930 -0.059525   -3.241267        -1.024388       -0.252568
#
#    Market Capitalization  Enterprise Value  Dividend Payout Ratio  \
# 0              -1.763040          0.324084              -0.385082
# 1              -0.802277         -0.161286               0.404051
# 2               0.473833         -1.191303               0.656554
# 3               1.135566          0.954002               0.651391
# 4              -1.247783          1.632411              -1.430141
#
#    Interest Expense  Tax Rate
# 0         -0.676922  0.611676
# 1          1.886186  0.174578
# 2         -0.974682  0.787085
# 3         -0.315269  0.758969
# 4         -0.440044  0.130741
#
# [5 rows x 54 columns]

# %%
financial_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Revenue                       12000 non-null  float64
#  1   Cost of Goods Sold            12000 non-null  float64
#  2   Gross Profit                  12000 non-null  float64
#  3   Operating Expenses            12000 non-null  float64
#  4   EBITDA                        12000 non-null  float64
#  5   Net Income                    12000 non-null  float64
#  6   Total Assets                  12000 non-null  float64
#  7   Total Liabilities             12000 non-null  float64
#  8   Equity                        12000 non-null  float64
#  9   Operating Cash Flow           12000 non-null  float64
#  10  Investing Cash Flow           12000 non-null  float64
#  11  Financing Cash Flow           12000 non-null  float64
#  12  Current Assets                12000 non-null  float64
#  13  Current Liabilities           12000 non-null  float64
#  14  Working Capital               12000 non-null  float64
#  15  Debt to Equity Ratio          12000 non-null  float64
#  16  Return on Assets              12000 non-null  float64
#  17  Return on Equity              12000 non-null  float64
#  18  Revenue Growth                12000 non-null  float64
#  19  Net Profit Margin             12000 non-null  float64
#  20  EBITDA Margin                 12000 non-null  float64
#  21  Interest Coverage Ratio       12000 non-null  float64
#  22  Earnings per Share            12000 non-null  float64
#  23  Book Value per Share          12000 non-null  float64
#  24  Dividend Yield                12000 non-null  float64
#  25  Price to Earnings Ratio       12000 non-null  float64
#  26  Price to Book Ratio           12000 non-null  float64
#  27  Free Cash Flow                12000 non-null  float64
#  28  Capital Expenditures          12000 non-null  float64
#  29  Inventory Turnover            12000 non-null  float64
#  30  Accounts Receivable Turnover  12000 non-null  float64
#  31  Accounts Payable Turnover     12000 non-null  float64
#  32  Days Sales Outstanding        12000 non-null  float64
#  33  Days Payable Outstanding      12000 non-null  float64
#  34  Days Inventory Outstanding    12000 non-null  float64
#  35  Asset Turnover                12000 non-null  float64
#  36  Current Ratio                 12000 non-null  float64
#  37  Quick Ratio                   12000 non-null  float64
#  38  Cash Ratio                    12000 non-null  float64
#  39  Debt Ratio                    12000 non-null  float64
#  40  Gross Margin                  12000 non-null  float64
#  41  Operating Margin              12000 non-null  float64
#  42  Net Profit Growth             12000 non-null  float64
#  43  ROIC                          12000 non-null  float64
#  44  EBIT                          12000 non-null  float64
#  45  NOPAT                         12000 non-null  float64
#  46  Total Debt                    12000 non-null  float64
#  47  Short-term Debt               12000 non-null  float64
#  48  Long-term Debt                12000 non-null  float64
#  49  Market Capitalization         12000 non-null  float64
#  50  Enterprise Value              12000 non-null  float64
#  51  Dividend Payout Ratio         12000 non-null  float64
#  52  Interest Expense              12000 non-null  float64
#  53  Tax Rate                      12000 non-null  float64
# dtypes: float64(54)
# memory usage: 4.9 MB

# %%
financial_data.describe()
# Out:
#             Revenue  Cost of Goods Sold  Gross Profit  Operating Expenses  \
# count  12000.000000        12000.000000  12000.000000        12000.000000
# mean      -0.000933           -0.014049      0.008183            0.008329
# std        1.006552            0.998812      0.999079            0.995499
# min       -3.593488           -3.904977     -3.793638           -3.999332
# 25%       -0.672261           -0.685200     -0.660215           -0.677369
# 50%       -0.007594           -0.010038      0.007422            0.016968
# 75%        0.669314            0.664011      0.679497            0.676284
# max        4.202026            4.678949      3.915816            3.775304
#
#              EBITDA    Net Income  Total Assets  Total Liabilities  \
# count  12000.000000  12000.000000  12000.000000       12000.000000
# mean      -0.004747     -0.005578      0.011096          -0.009311
# std        1.005940      1.002396      0.997523           1.002214
# min       -3.727692     -4.164295     -3.604870          -3.831045
# 25%       -0.685446     -0.683076     -0.661116          -0.692953
# 50%        0.003003     -0.002903      0.030384          -0.014376
# 75%        0.683716      0.661778      0.686081           0.663229
# max        3.681377      3.942331      3.541436           4.611257
#
#              Equity  Operating Cash Flow  ...          EBIT         NOPAT  \
# count  12000.000000         12000.000000  ...  12000.000000  12000.000000
# mean      -0.003329             0.009444  ...     -0.003276      0.002033
# std        0.999216             0.996550  ...      1.006700      1.001858
# min       -4.189234            -3.814205  ...     -3.997015     -3.719918
# 25%       -0.681307            -0.663345  ...     -0.683681     -0.675810
# 50%       -0.003392            -0.000210  ...      0.001566      0.010920
# 75%        0.675625             0.670515  ...      0.684918      0.675343
# max        3.609479             3.699115  ...      3.813848      3.699576
#
#          Total Debt  Short-term Debt  Long-term Debt  Market Capitalization  \
# count  12000.000000     12000.000000    12000.000000           12000.000000
# mean       0.010844        -0.012888       -0.002405               0.001833
# std        1.004573         1.002327        1.004159               1.011160
# min       -3.836656        -3.658791       -4.003598              -4.251364
# 25%       -0.675514        -0.685913       -0.680501              -0.686768
# 50%        0.015978        -0.022081       -0.002382              -0.006712
# 75%        0.690169         0.659521        0.671198               0.689792
# max        3.811216         4.065773        3.727421               3.760155
#
#        Enterprise Value  Dividend Payout Ratio  Interest Expense      Tax Rate
# count      12000.000000           12000.000000      12000.000000  12000.000000
# mean           0.018023               0.000993          0.008479     -0.000726
# std            0.992988               0.994767          0.998613      0.994195
# min           -3.922400              -3.802631         -4.312973     -3.841796
# 25%           -0.666081              -0.670928         -0.662742     -0.668460
# 50%            0.018705              -0.000502          0.012565     -0.005657
# 75%            0.693987               0.668506          0.688185      0.672658
# max            3.829782               3.804390          3.547591      3.782188
#
# [8 rows x 54 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(financial_data.corr(), cmap="coolwarm", annot=False)
plt.title("Correlation Matrix of Financial Indicators")
plt.show()

# %%
key_metrics = ['Revenue', 'Net Income', 'Equity', 'Total Debt', 'Debt to Equity Ratio', 'Return on Assets', 'Return on Equity']
for metric in key_metrics:
    plt.figure(figsize=(8, 5))
    sns.histplot(financial_data[metric], bins=50, kde=True)
    plt.title(f"Distribution of {metric}")
    plt.xlabel(metric)
    plt.ylabel("Frequency")
    plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=financial_data[['Debt to Equity Ratio', 'Return on Assets', 'Return on Equity', 'Net Profit Margin', 'EBITDA Margin']])
plt.title("Boxplot of Financial Ratios")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x=financial_data['Revenue'], y=financial_data['Net Income'])
plt.title("Revenue vs. Net Income")
plt.xlabel("Revenue")
plt.ylabel("Net Income")
plt.show()

# %%
subset = financial_data[['Revenue', 'Net Income', 'EBITDA', 'Total Assets', 'Total Liabilities']]
sns.pairplot(subset)
plt.show()

# %%
selected_features = ['Net Income', 'EBITDA Margin', 'Return on Assets', 'Return on Equity', 'Debt to Equity Ratio', 
                     'Interest Coverage Ratio', 'Operating Cash Flow', 'Free Cash Flow', 'Revenue Growth', 'Current Ratio']

plt.figure(figsize=(10, 6))
sns.heatmap(financial_data[selected_features].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Between Selected Financial Features")
plt.show()

# %%
sns.pairplot(financial_data[selected_features])
plt.show()
